# %%
import yfinance

# %%
btc_usd = yfinance.Ticker('BTC-USD')

# %%
hist = btc_usd.history(period='1mo', interval='1h')

# %%
hist
# Out:
#                                    Open          High           Low  \
# Datetime
# 2023-03-09 12:00:00+00:00  21674.878906  21679.451172  21621.976562
# 2023-03-09 13:00:00+00:00  21624.003906  21720.484375  21588.546875
# 2023-03-09 14:00:00+00:00  21710.484375  21796.121094  21702.820312
# 2023-03-09 15:00:00+00:00  21720.011719  21777.724609  21668.378906
# 2023-03-09 16:00:00+00:00  21668.062500  21669.951172  21506.064453
# ...                                 ...           ...           ...
# 2023-04-09 08:00:00+00:00  27920.966797  27938.755859  27847.158203
# 2023-04-09 09:00:00+00:00  27897.750000  27947.687500  27896.910156
# 2023-04-09 10:00:00+00:00  27914.250000  27925.875000  27892.849609
# 2023-04-09 11:00:00+00:00  27902.494141  27947.484375  27883.878906
# 2023-04-09 12:00:00+00:00  27947.794922  27979.201172  27938.392578
#
#                                   Close     Volume  Dividends  Stock Splits
# Datetime
# ...

# %%
btc_usd.history_metadata
# Out:
# {'currency': 'USD',
#  'symbol': 'BTC-USD',
#  'exchangeName': 'CCC',
#  'instrumentType': 'CRYPTOCURRENCY',
#  'firstTradeDate': 1410912000,
#  'regularMarketTime': 1681043460,
#  'gmtoffset': 0,
#  'timezone': 'UTC',
#  'exchangeTimezoneName': 'UTC',
#  'regularMarketPrice': 27979.201,
#  'chartPreviousClose': 20363.021,
#  'previousClose': 27946.512,
#  'scale': 3,
#  'priceHint': 2,
#  'currentTradingPeriod': {'pre': {'timezone': 'UTC',
#    'start': 1680998400,
#    'end': 1680998400,
#    'gmtoffset': 0},
#   'regular': {'timezone': 'UTC',
#    'start': 1680998400,
#    'end': 1681084740,
#    'gmtoffset': 0},
#   'post': {'timezone': 'UTC',
#    'start': 1681084740,
#    'end': 1681084740,
#    'gmtoffset': 0}},
#  'tradingPeriods': [[{'timezone': 'UTC',
#     'start': 1678320000,
#     'end': 1678406340,
#     'gmtoffset': 0}],
#   [{'timezone': 'UTC',
#     'start': 1678406400,
#     'end': 1678492740,
#     'gmtoffset': 0}],
#   [{'timezone': 'UTC',
# ...

# %%
unable = yfinance.Ticker('UUSNNF')

# %%
unable.hist
# Out:
# yfinance.Ticker object <UUSNNF>
